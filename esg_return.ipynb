# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
esg = pd.read_excel('/content/drive/MyDrive/esg_final_dummy_std.xlsx')
esg
# Out:
#      Unnamed: 0  Unnamed: 0.1  company  ...  sector_8  sector_9       std
# 0             0             0  BNK금융지주  ...         0         0  0.023789
# 1             1             1  DGB금융지주  ...         0         0  0.025930
# 2             2             2   JB금융지주  ...         0         0  0.022942
# 3             3             3     KB금융  ...         0         0  0.029796
# 4             4             4    S-Oil  ...         0         1  0.031155
# ..          ...           ...      ...  ...       ...       ...       ...
# 556         556           556    화인베스틸  ...         0         1  0.043024
# 557         557           557     환인제약  ...         0         1  0.024040
# 558         558           558      휴온스  ...         0         1  0.032674
# 559         559           559   휴온스글로벌  ...         0         1  0.029663
# 560         560           560     흥국화재  ...         0         0  0.037623
#
# [561 rows x 25 columns]

# %%
del esg['Unnamed: 0','Unnamed: 0.1']
esg.columns = ['company', 'code', 'esg', 'e', 's', 'g', 'year', 'AV','ret']
esg.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Unnamed: 0', 'Unnamed: 0.1')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-fc1e3d3e8d1f> in <module>()
# ...

# %%
pip install -U finance-datareader

# %%
import FinanceDataReader as fdr
esg.code = esg.code.map('{:06d}'.format)
esg['ret_2'] = 0.0
esg
# Out:
#      Unnamed: 0  Unnamed: 0.1  company  ... sector_9       std  ret_2
# 0             0             0  BNK금융지주  ...        0  0.023789    0.0
# 1             1             1  DGB금융지주  ...        0  0.025930    0.0
# 2             2             2   JB금융지주  ...        0  0.022942    0.0
# 3             3             3     KB금융  ...        0  0.029796    0.0
# 4             4             4    S-Oil  ...        1  0.031155    0.0
# ..          ...           ...      ...  ...      ...       ...    ...
# 556         556           556    화인베스틸  ...        1  0.043024    0.0
# 557         557           557     환인제약  ...        1  0.024040    0.0
# 558         558           558      휴온스  ...        1  0.032674    0.0
# 559         559           559   휴온스글로벌  ...        1  0.029663    0.0
# 560         560           560     흥국화재  ...        0  0.037623    0.0
#
# [561 rows x 26 columns]

# %%
for x in code :
    s = fdr.DataReader(symbol=x, start='20200101', end='20201231')
    ret = (s.iloc[247][3]-s.iloc[0][3])/(s.iloc[0][3])
    RET.append(ret)
data['ret']=RET
data

# %%
for i in range(0, len(esg)) :
    df = fdr.DataReader(symbol=str(esg.code[i]), start='20200501', end='20201231')
    ret_2 = df.Close.pct_change().mean()
    esg['ret_2'][i] = ret_2 
esg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      Unnamed: 0  Unnamed: 0.1  company  ... sector_9       std     ret_2
# 0             0             0  BNK금융지주  ...        0  0.023789  0.001164
# 1             1             1  DGB금융지주  ...        0  0.025930  0.001878
# 2             2             2   JB금융지주  ...        0  0.022942  0.001317
# 3             3             3     KB금융  ...        0  0.029796  0.001921
# 4             4             4    S-Oil  ...        1  0.031155  0.000345
# ..          ...           ...      ...  ...      ...       ...       ...
# 556         556           556    화인베스틸  ...        1  0.043024  0.002450
# ...

# %%
esg['ret_3'] = 0.0
esg

for i in range(0, len(esg)) :
    df = fdr.DataReader(symbol=str(esg.code[i]), start='20201001', end='20210430')
    ret_3 = df.Close.pct_change().mean()
    esg['ret_3'][i] = ret_3 
esg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Unnamed: 0  Unnamed: 0.1  company  ...       std     ret_2     ret_3
# 0             0             0  BNK금융지주  ...  0.023789  0.001164  0.003082
# 1             1             1  DGB금융지주  ...  0.025930  0.001878  0.003582
# 2             2             2   JB금융지주  ...  0.022942  0.001317  0.003415
# 3             3             3     KB금융  ...  0.029796  0.001921  0.002595
# 4             4             4    S-Oil  ...  0.031155  0.000345  0.003700
# ..          ...           ...      ...  ...       ...       ...       ...
# 556         556           556    화인베스틸  ...  0.043024  0.002450  0.002344
# 557         557           557     환인제약  ...  0.024040  0.001165  0.002430
# ...

# %%
import FinanceDataReader as fdr

# %%
esg.to_excel('esg_return_final_1.xlsx')
